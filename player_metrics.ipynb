# %% [markdown]
# ## Data Collection

# %%
import pandas as pd

# %%
data = pd.read_csv('Seasons_Stats.csv')

# %%
data.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...  \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
data['Year']= pd.to_numeric(data['Year'])

# %%
data.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...  \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Apply Constraints to Data

# %% [markdown]
# 1. We only want player data from 1980s onwards which has advanced stats
# 2. We are only considering veterans who we defined as 30 years or more
# 3. Set minimum games played to 20, so we reduce outliers.

# %%
data = data[data['Year'] > 1980]

# %%
data = data[data['Age'] >= 30]

# %%
data = data[data['G'] >= 20]
data = data[data['MP'] >= 1000]

# %%
data.tail()
# Out:
#          Year           Player Pos   Age   Tm     G    GS      MP   PER  \
# 24662  2017.0   Deron Williams  PG  32.0  DAL  40.0  40.0  1171.0  15.0
# 24667  2017.0     Lou Williams  SG  30.0  TOT  81.0   1.0  1994.0  21.4
# 24668  2017.0     Lou Williams  SG  30.0  LAL  58.0   1.0  1403.0  23.9
# 24670  2017.0  Marvin Williams  PF  30.0  CHO  76.0  76.0  2295.0  13.7
# 24684  2017.0       Nick Young  SG  31.0  LAL  60.0  60.0  1556.0  14.1
#
#          TS%  ...    FT%   ORB    DRB    TRB    AST   STL   BLK    TOV     PF  \
# 24662  0.533  ...  0.821  13.0   89.0  102.0  274.0  25.0   2.0   98.0   96.0
# 24667  0.593  ...  0.880  26.0  176.0  202.0  239.0  80.0  19.0  160.0   92.0
# 24668  0.609  ...  0.884  14.0  118.0  132.0  183.0  65.0  10.0  120.0   67.0
# 24670  0.551  ...  0.873  89.0  409.0  498.0  106.0  58.0  53.0   60.0  134.0
# 24684  0.588  ...  0.856  25.0  112.0  137.0   58.0  37.0  14.0   36.0  137.0
#
#           PTS
# 24662   522.0
# 24667  1421.0
# 24668  1078.0
# ...

# %% [markdown]
# ### Extract players who were traded

# %%
from collections import defaultdict

def remove_redundant(data):
    a = defaultdict(list)
    ind_to_remove = []
    for index, row in data.iterrows():
        if row.Player in a[row.Year]:
            ind_to_remove.append(index)
        else:
            a[row.Year].append(row.Player)
    data = data.drop(index=ind_to_remove)
    return data

# %%
data = remove_redundant(data)

# %%
data[data['Player']=='Deron Williams']
# Out:
#          Year          Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 23485  2015.0  Deron Williams  PG  30.0  BRK  68.0  55.0  2114.0  15.7  0.504
# 24076  2016.0  Deron Williams  PG  31.0  DAL  65.0  63.0  2106.0  14.6  0.530
# 24661  2017.0  Deron Williams  PG  32.0  TOT  64.0  44.0  1657.0  14.0  0.541
#
#        ...    FT%   ORB    DRB    TRB    AST   STL   BLK    TOV     PF    PTS
# 23485  ...  0.834  29.0  208.0  237.0  448.0  64.0  17.0  154.0  157.0  884.0
# 24076  ...  0.869  19.0  171.0  190.0  378.0  61.0  14.0  150.0  155.0  918.0
# 24661  ...  0.826  14.0  133.0  147.0  360.0  31.0   8.0  138.0  138.0  701.0
#
# [3 rows x 52 columns]

# %% [markdown]
# ### Data Collection/Cleaning from Kaggle and Basketball Reference

# %%
data_2020 = pd.read_csv("nba_2020_advanced.csv")
data_2021 = pd.read_csv("nba_2021.csv")
data_2018 = pd.read_csv("nba_2018.csv")
data_2019 = pd.read_csv("nba-2019.csv")

# %%
data_2020.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
data_2021.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
data_2018.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
data_2019.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# ## Feature Choosing

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

corr = data.corr()
# Make a heatmap with highlights on pairs of features with high correlations.
corr_annot = corr.round(2)
corr_annot[corr_annot.abs()<0.8] = ''
_ = plt.figure(figsize=(16, 12))
_ = sns.heatmap(corr, annot=corr_annot, cmap='coolwarm', fmt='')

# %% [markdown]
# It appears a lot of these stats are highly correlated with each other. Counting stats are highly correlated to their % counterparts. And because counting stats are highly affected by playing time it only makes sense to use % stats. So let's focus on the advanced stats and look at their heatmaps.

# %%
corr = data_2020.corr()
# Make a heatmap with highlights on pairs of features with high correlations.
corr_annot = corr.round(2)
corr_annot[corr_annot.abs()<0.8] = ''
_ = plt.figure(figsize=(16, 12))
_ = sns.heatmap(corr, annot=corr_annot, cmap='coolwarm', fmt='')

# %% [markdown]
# As you can see. The 2019-2020 season data is advanced stats. DRB % is highly correlated with TRB% so let's just not include total stats for this. Since we have OWS and DWS it doesn't make sense to include WS as that is just a net total of two other features, same goes for BPM. VORP is a highly offensive focused statistic on player creation and scoring per 100 possessions, which is why it is highly correlated with OWS. Let's drop these total metric measures, counting stats that are already accounted for, and advanced stats that are highly correlated.

# %%
data = data.drop(['blanl', 'blank2', 'BPM', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
       'BLK', 'TOV', 'PTS', 'GS', 'VORP', 'TRB%'],axis=1)

# %%
#Add columns if needed
data_2020.insert(0,'Year',2020)
data_2018.insert(0,'Year',2018)
data_2019.insert(0,'Year',2019)
data_2021.insert(0,'Year',2021)

# %%
#Drop necessary columns
data_2020 = data_2020.drop(['VORP', 'BPM', 'TRB%'],axis=1)
data_2021 = data_2021.drop(['Rk','VORP', 'BPM', 'TRB%'],axis=1)
data_2018 = data_2018.drop(['Rk', 'TRB%','Unnamed: 19','Unnamed: 24','BPM', 'VORP'],axis=1)
data_2019 = data_2019.drop(['Rk', 'TRB%', 'BPM', 'VORP'],axis=1)

# %% [markdown]
# Now let's apply our constraints to the 2019 data like we did to the bulk player data.

# %%
data_2020 = data_2020[data_2020['Age'] >= 30]
data_2018 = data_2018[data_2018['Age'] >= 30]
data_2021 = data_2021[data_2021['Age'] >= 30]
data_2019 = data_2019[data_2019['Age'] >= 30]

# %%
data_2020 = data_2020[data_2020['G'] >= 20]
data_2018 = data_2018[data_2018['G'] >= 20]
data_2021 = data_2021[data_2021['G'] >= 20]
data_2019 = data_2019[data_2019['G'] >= 20]

# %%
data_2020 = data_2020[data_2020['MP'] >= 1000]
data_2018 = data_2018[data_2018['MP'] >= 1000]
data_2021 = data_2021[data_2021['MP'] >= 1000]
data_2019 = data_2019[data_2019['MP'] >= 1000]

# %%
data_2020 = remove_redundant(data_2020)
data_2018 = remove_redundant(data_2018)
data_2021 = remove_redundant(data_2021)
data_2019 = remove_redundant(data_2019)

changes = [data_2018,data_2019,data_2021]

#Make syntax changes if needed
for i in changes:
    temp = []
    for p in i['Player']:  
        temp.append(p.split('\\')[0])

    i['Player'] = temp

# %%
data_2020.tail()
# Out:
#      Year             Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 623  2020  Russell Westbrook  PG   31  HOU  57  2049  21.0  0.536  0.166  ...
# 626  2020   Hassan Whiteside   C   30  POR  67  2008  25.0  0.644  0.010  ...
# 633  2020       Lou Williams  SG   33  LAC  65  1864  17.3  0.546  0.337  ...
# 634  2020    Marvin Williams  PF   33  TOT  58  1129  11.2  0.587  0.584  ...
# 645  2020     Thaddeus Young  PF   31  CHI  64  1591  13.3  0.521  0.369  ...
#
#      STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM
# 623   2.1   0.8  15.0  34.4  1.7  2.5  4.2  0.098   1.6  -0.1
# 626   0.6   8.4  12.9  19.6  5.6  3.0  8.5  0.204   2.5   0.7
# 633   1.1   0.6  14.4  28.4  2.3  1.8  4.1  0.105   2.2  -1.4
# 634   1.6   2.4  10.2  12.5  1.1  1.3  2.4  0.102  -1.6   1.0
# 645   2.8   1.4  13.9  19.7 -0.2  2.1  1.9  0.058  -1.4   0.2
#
# [5 rows x 24 columns]

# %%
data_2018.tail()
# Out:
#      Year           Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 592  2018      P.J. Tucker  PF   32  HOU  82  2281   8.3  0.537  0.703  ...
# 608  2018      Dwyane Wade  SG   36  TOT  67  1536  15.0  0.500  0.163  ...
# 637  2018     Lou Williams  SG   31  LAC  79  2589  20.2  0.574  0.387  ...
# 638  2018  Marvin Williams  PF   31  CHO  78  2006  13.9  0.603  0.542  ...
# 655  2018       Nick Young  SG   32  GSW  80  1393  10.0  0.562  0.668  ...
#
#      STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM
# 592   1.7   1.0  13.7  10.5  1.0  3.0  3.9  0.082  -1.5   1.5
# 608   2.0   2.6  15.5  26.2 -0.4  1.6  1.1  0.036  -2.4   0.3
# 637   1.6   0.6  13.1  29.8  5.5  1.2  6.7  0.125   3.8  -2.9
# 638   1.4   1.6   9.7  14.8  3.1  1.9  5.0  0.119   1.1   0.5
# 655   1.3   0.4   7.2  17.6  0.8  0.9  1.7  0.058  -0.2  -3.4
#
# [5 rows x 24 columns]

# %%
data_2021.tail()
# Out:
#      Year             Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 665  2021          John Wall  PG   30  HOU  40  1288  15.4  0.503  0.343  ...
# 666  2021     Brad Wanamaker  PG   31  TOT  61  1053   9.5  0.489  0.284  ...
# 675  2021  Russell Westbrook  PG   32  WAS  65  2369  19.5  0.509  0.221  ...
# 683  2021       Lou Williams  PG   34  TOT  66  1423  14.0  0.519  0.268  ...
# 701  2021     Thaddeus Young  PF   32  CHI  68  1652  20.3  0.578  0.068  ...
#
#      STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM
# 665   1.5   2.1  14.7  31.7 -1.0  0.8 -0.2 -0.007   1.4  -1.6
# 666   1.9   1.0  17.1  16.9 -0.2  1.0  0.9  0.039  -4.6  -0.2
# 675   1.7   0.8  18.0  30.2  0.5  3.2  3.7  0.075   2.5   0.8
# 683   1.6   0.4  13.0  25.7  0.5  1.2  1.7  0.056  -1.1  -1.8
# 701   2.2   2.1  16.1  22.3  2.8  2.2  5.1  0.147   2.0   1.2
#
# [5 rows x 24 columns]

# %%
data_2019.tail()
# Out:
#      Year             Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 663  2019        Dwyane Wade  SG   37  MIA  72  1885  15.8  0.510  0.272  ...
# 675  2019  Russell Westbrook  PG   30  OKC  73  2630  21.1  0.501  0.279  ...
# 684  2019       Lou Williams  SG   32  LAC  75  1993  21.2  0.554  0.256  ...
# 685  2019    Marvin Williams  PF   32  CHO  75  2133  12.6  0.548  0.586  ...
# 698  2019     Thaddeus Young  PF   30  IND  81  2489  16.2  0.569  0.174  ...
#
#      STL%  BLK%  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM
# 663   1.5   1.8  13.5  27.9  0.1  2.3  2.4  0.061   0.8  -0.2
# 675   2.5   1.1  16.3  30.9  1.8  5.0  6.8  0.124   2.8   2.4
# 684   1.3   0.4  11.8  32.4  3.9  1.2  5.1  0.123   4.3  -2.1
# 685   1.6   2.5   6.4  14.9  1.9  1.9  3.8  0.086  -0.4   0.2
# 698   2.4   1.3  12.0  18.0  3.0  3.9  6.9  0.133   0.4   1.1
#
# [5 rows x 24 columns]

# %%
dlist = [data_2018,data_2019,data_2020,data_2021]
new_data = pd.concat(dlist)

d2 = [data,new_data]
final = pd.concat(d2)

# %%
final.head()
# Out:
#         Year                Player Pos   Age   Tm     G      MP   PER    TS%  \
# 6085  1981.0  Kareem Abdul-Jabbar*   C  33.0  LAL  80.0  2976.0  25.5  0.616
# 6091  1981.0       Tiny Archibald*  PG  32.0  BOS  80.0  2820.0  14.3  0.582
# 6099  1981.0           Henry Bibby  PG  31.0  SDC  73.0  1112.0  10.6  0.480
# 6103  1981.0             Ron Boone  SG  34.0  UTA  52.0  1146.0   9.0  0.492
# 6115  1981.0            Fred Brown  SG  32.0  SEA  78.0  1986.0  18.3  0.535
#
#        3PAr  ...    WS  WS/48  OBPM  DBPM    FG%    3P%    2P%   eFG%    FT%  \
# 6085  0.001  ...  14.3  0.230   3.9   1.4  0.574  0.000  0.574  0.574  0.766
# 6091  0.012  ...   6.9  0.118   0.4  -1.6  0.499  0.000  0.505  0.499  0.816
# 6099  0.310  ...   1.0  0.043  -1.4  -2.3  0.386  0.337  0.408  0.438  0.684
# 6103  0.105  ...  -0.6 -0.025  -3.4  -2.8  0.431  0.282  0.449  0.446  0.798
# 6115  0.062  ...   5.2  0.127   2.2  -1.8  0.488  0.359  0.496  0.499  0.832
#
#          PF
# 6085  244.0
# 6091  201.0
# ...

# %%
data_2019.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS',
#        'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'FG%', '3P%', '2P%', 'eFG%',
#        'FT%', 'PF'],
#       dtype='object')
